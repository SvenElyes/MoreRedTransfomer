# %%
import os
os.environ["OMP_NUM_THREADS"] = "6" # export OMP_NUM_THREADS=4
os.environ["OPENBLAS_NUM_THREADS"
] = "6" # export OPENBLAS_NUM_THREADS=4
os.environ["MKL_NUM_THREADS"] = "6" # export MKL_NUM_THREADS=6

# %%
from matplotlib import pyplot as plt

import torch

import os
import sys
print("nihao")
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))

# Add src to the system path
if src_path not in sys.path:
    sys.path.insert(0, src_path)



from omegaconf import OmegaConf
from ase.visualize.plot import plot_atoms
from ase import Atoms
from schnetpack import properties
import schnetpack.transform as trn
from schnetpack.datasets import QM9
from tqdm import tqdm
import ase

from morered.datasets import QM9Filtered, QM7X
from morered.noise_schedules import PolynomialSchedule
from morered.processes import VPGaussianDDPM
from morered.utils import scatter_mean, check_validity, generate_bonds_data, batch_center_systems
from morered.sampling import DDPM, MoreRedJT, MoreRedAS, MoreRedITP
# Out:
# nihao

# %% [markdown]
# # Structure Generation/Denoising tutorial
#
# This notebook explains how to use the models, for structure relaxation/denoising or generation from scratch, after training. You can find pre-trained models in under "models/" directory.
#
# ## 1. Define sampler
# How to instantiate the different samplers.
#
# ## 2. Define data loader
# How to load data from ase.db database.
#
# ## 3. Relaxating batches of diffused data
# How to diffuse a batch of structures and denoise them using the different models.
#
# ## 4. Load your own xyz file
# How to load molecules from your own xyz files and denoise them.
#
# ## 5. Sample from scratch
# How to sample new stuctures from scratch given an atomic composition.

# %% [markdown]
# # Helper functions

# %%
def plot_batch_molecules(batch):
    n_cols = len(batch[properties.idx_m].unique())
    n_rows = 1

    fig, axs = plt.subplots(n_rows, n_cols, figsize=(3 * n_cols, 3 * n_rows))
    axs = axs.flatten()

    for i, ax in enumerate(axs):
        mask = batch[properties.idx_m] == i
        mol = Atoms(numbers=batch[properties.Z][mask], positions=batch[properties.R][mask])

        plot_atoms(mol, ax)
        ax.axis("off")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Paths

# %%
# path to store the dataset as ASE '.db' files
split_file_path = "split.npz"

# model path
models_path = "../models"

# %% [markdown]
# # Load models

# %%
# MoreRed-JT: joint denoiser and time predictor
morered_jt = torch.load(os.path.join(models_path, "qm9_morered_jt.pt"), map_location="cpu")

# MoreRed-AS, MoreRed-ITP and plain DDPM use the same denoier model
ddpm_denoiser = torch.load(os.path.join(models_path, "qm9_ddpm.pt"), map_location="cpu")

# Seperate model for time prediction for MoreRed-AS and MoreRed-ITP
time_predictor = torch.load(os.path.join(models_path, "qm9_time_predictor.pt"), map_location="cpu")
# Out:
# /tmp/ipykernel_2653890/556669235.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   morered_jt = torch.load(os.path.join(models_path, "qm9_morered_jt.pt"), map_location="cpu")
# /tmp/ipykernel_2653890/556669235.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ddpm_denoiser = torch.load(os.path.join(models_path, "qm9_ddpm.pt"), map_location="cpu")
# /tmp/ipykernel_2653890/556669235.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   time_predictor = torch.load(os.path.join(models_path, "qm9_time_predictor.pt"), map_location="cpu")

# %% [markdown]
# # Define sampler

# %%
# define the noise schedule
noise_schedule = PolynomialSchedule(T=1000, s=1e-5, dtype=torch.float64, variance_type="lower_bound")

# define the forward diffusion process
diff_proc = VPGaussianDDPM(noise_schedule, noise_key="eps", invariant=True, dtype=torch.float64)

# %%
ddpm_sampler = DDPM(
    diff_proc,
    ddpm_denoiser,
    time_key="t",
    noise_pred_key="eps_pred",
    cutoff=5.,
    recompute_neighbors=False,
    save_progress= True,
    progress_stride = 1,
    results_on_cpu = True,
)

# %%
mrd_jt_sampler = MoreRedJT(
    diff_proc,
    morered_jt,
    noise_pred_key="eps_pred",
    time_key="t",
    time_pred_key="t_pred",
    convergence_step=0,
    cutoff=5.,
    recompute_neighbors=False,
    save_progress= True,
    progress_stride = 1,
    results_on_cpu = True
)

# %%
mrd_as_sampler = MoreRedAS(
    diff_proc,
    ddpm_denoiser,
    time_predictor,
    noise_pred_key="eps_pred",
    time_pred_key="t_pred",
    time_key="t",
    cutoff=5.,
    recompute_neighbors=False,
    save_progress= True,
    progress_stride = 1,
    results_on_cpu = True
)

# %%
mrd_itp_sampler = MoreRedITP(
    diff_proc,
    ddpm_denoiser,
    time_predictor,
    noise_pred_key="eps_pred",
    time_pred_key="t_pred",
    time_key="t",
    cutoff=5.,
    recompute_neighbors=False,
    save_progress= True,
    progress_stride = 1,
    results_on_cpu = True
)

# %% [markdown]
# # Define data loader

# %% [markdown]
# Define paths

# %%
tut_path = "./tut"

# %%
os.makedirs(tut_path, exist_ok=True)

# %% [markdown]
# Define data input transformations

# %%
transforms=[
    trn.CastTo64(),
    trn.SubtractCenterOfGeometry(),
]

# %% [markdown]
# Define dataset

# %% [markdown]
# QM9

# %%
# path to store the dataset as ASE '.db' files
#datapath = os.path.join(tut_path, "qm9.db")


#Changes made to accomodate hydra fast laoding

#tut_path = "./tut" deprecated
#our dataset is in hydra temp folder.

# Absolute path inside container to the mounted dataset
dataset_path = "/input-data/energy_U0"
# path to store the dataset as ASE '.db' files
datapath = os.path.join(dataset_path, "qm9.db") 

# path to store the dataset as ASE '.db' files
split_file_path = os.path.join(dataset_path, "split.npz")

# %%
data = QM9Filtered(
    datapath=datapath,
    batch_size=8,
    remove_uncharacterized=False, #true
    num_train=3000,
    num_val=3000,
    num_test=3000,
    transforms=transforms,
    num_workers=2,
    pin_memory=False,
)

# %% [markdown]
# QM7X

# %% [markdown]
# NOTE! QM7-X is large. Therefore, it takes time to download the dataset and prepare it

# %%
# path to store the dataset as ASE '.db' files
# datapath = os.path.join(tut_path, "qm7x.db")

# %%
# data = QM7X(
#     datapath=datapath,
#     only_equilibrium=False,
#     batch_size=8,
#     transforms=transforms,
#     num_train=128,
#     num_val=128,
#     num_test=128,
#     num_workers=2,
#     pin_memory=False,
#     load_properties=["rmsd"],
# )

# %% [markdown]
# Prepare dataset

# %%
# prepare and setup the dataset
data.prepare_data()
data.setup()

# %% [markdown]
# # Relaxing batches of diffused data

# %% [markdown]
# Load a batch

# %%
# train split here is not the same as during training
batch = next(iter(data.train_dataloader()))

# %%
plot_batch_molecules(batch)

# %% [markdown]
# Diffuse the batch

# %%
# define the time step
t = 150

# %%
batch[properties.R], _ = diff_proc.diffuse(batch[properties.R], batch[properties.idx_m], t=torch.tensor(t))

# %%
# check if the centre of geometry for the molecules and sampled noise is zero
assert (scatter_mean(batch[properties.R], batch[properties.idx_m], batch[properties.n_atoms]) < 1e-5).all()

# %%
plot_batch_molecules(batch)

# %% [markdown]
# Denoise

# %%
# ddpm require time step as input
relaxed_ddpm, num_steps_ddpm, hist_ddpm = ddpm_sampler.denoise(batch, t=t)

# morered models dont need time step as input but max steps to interrupt the denoising process
relaxed_jt, num_steps_jt, hist_jt = mrd_jt_sampler.denoise(batch, max_steps=1000)
relaxed_as, num_steps_as, hist_as = mrd_as_sampler.denoise(batch, max_steps=1000)
relaxed_itp, num_steps_itp, hist_itp = mrd_itp_sampler.denoise(batch, max_steps=1000)
print("done")
# Out:
# 100%|██████████| 150/150 [00:06<00:00, 23.99it/s]
# 1000it [00:38, 25.77it/s]
# 1000it [01:02, 15.88it/s]
# 213it [00:06, 31.71it/s]

# %%
print("Num steps per example DDPM: ", num_steps_ddpm)
print("Num steps per example MoreRed-JT: ", num_steps_jt)
print("Num steps per example MoreRed-AS: ", num_steps_as)
print("Num steps per example MoreRed-ITP: ", num_steps_itp)
# Out:
# Num steps per example DDPM:  tensor([150, 150, 150, 150, 150, 150, 150, 150])
# Num steps per example MoreRed-JT:  tensor([-1, -1, -1, -1, -1, -1, -1, -1])
# Num steps per example MoreRed-AS:  tensor([-1, -1, -1, -1, -1, -1, -1, -1])
# Num steps per example MoreRed-ITP:  tensor([183, 213, 163, 178, 150, 120, 149, 109])

# %%
# plot the different examples
tmp_batch = {key: val.clone() for key, val in batch.items()}

print("DDPM:")
tmp_batch.update(relaxed_ddpm)
plot_batch_molecules(tmp_batch)

print("MoreRed-JT:")
tmp_batch.update(relaxed_jt)
plot_batch_molecules(tmp_batch)

print("MoreRed-AS:")
tmp_batch.update(relaxed_as)
plot_batch_molecules(tmp_batch)

print("MoreRed-ITP:")
tmp_batch.update(relaxed_itp)
plot_batch_molecules(tmp_batch)
# Out:
# DDPM:
# MoreRed-JT:
# MoreRed-AS:
# MoreRed-ITP:

# %%
# check validity of the molecules for each method
# Note this is just a simple check that can't e.g. recognize aromatic rings, check cG-SchNet Gebauer et al. for the analysis scripts

bonds_data = generate_bonds_data().values()

tmp_batch.update(relaxed_ddpm)
validity_ddpm = check_validity(tmp_batch, *bonds_data)
print("Validity DDPM: ", validity_ddpm['stable_molecules'])

tmp_batch.update(relaxed_jt)
validity_jt = check_validity(tmp_batch, *bonds_data)
print("Validity MoreRed-JT: ", validity_jt['stable_molecules'])

tmp_batch.update(relaxed_as)
validity_as = check_validity(tmp_batch, *bonds_data)
print("Validity MoreRed-AS: ", validity_as['stable_molecules'])

tmp_batch.update(relaxed_itp)
validity_itp = check_validity(tmp_batch, *bonds_data)
print("Validity MoreRed-ITP: ", validity_itp['stable_molecules'])
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 2907.16it/s]
# Validity DDPM:  [True, True, True, True, True, True, True, True]
# 100%|██████████| 8/8 [00:00<00:00, 2928.98it/s]
# Validity MoreRed-JT:  [True, True, True, True, True, True, True, True]
# 100%|██████████| 8/8 [00:00<00:00, 2887.15it/s]
# Validity MoreRed-AS:  [True, True, True, True, True, True, True, True]
# 100%|██████████| 8/8 [00:00<00:00, 2780.45it/s]
# Validity MoreRed-ITP:  [True, True, True, True, True, True, True, True]

# %% [markdown]
# # Load your own xyz file

# %%
examp = ase.io.read("example.xyz")

batch = mrd_jt_sampler.prepare_inputs(examp)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 examp = ase.io.read("example.xyz")
#       3 batch = mrd_jt_sampler.prepare_inputs(examp)
#
# File /usr/local/lib/python3.8/site-packages/ase/io/formats.py:793, in read(filename, index, format, parallel, do_not_split_by_at_sign, **kwargs)
#     791 if index is None:
#     792     index = -1
# --> 793 format = format or filetype(filename, read=isinstance(filename, str))
#     795 io = get_ioformat(format)
#     796 if isinstance(index, (slice, str)):
#
# File /usr/local/lib/python3.8/site-packages/ase/io/formats.py:965, in filetype(filename, read, guess)
#     962     return ext
#     964 if orig_filename == filename:
# --> 965     fd = open_with_compression(filename, 'rb')
#     966 else:
#     967     fd = orig_filename  # type: ignore[assignment]
#
# File /usr/local/lib/python3.8/site-packages/ase/io/formats.py:597, in open_with_compression(filename, mode)
#     594     return lzma.open(filename, mode)
#     595 else:
#     596     # Either None or unknown string
# --> 597     return open(filename, mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.xyz'

# %%
print("Before relaxation:")
plot_atoms(examp)
plt.axis("off")
plt.show()
# Out:
# Before relaxation:

# %%
relaxed, num_steps, hist = mrd_jt_sampler.denoise(batch, max_steps=1000)
# Out:
# 1000it [00:11, 84.26it/s]

# %%
examp.positions = relaxed[properties.R].numpy()

print("After relaxation:")
plot_atoms(examp)
plt.axis("off")
plt.show()
# Out:
# After relaxation:

# %% [markdown]
# # Sample from scratch

# %% [markdown]
# Load a batch

# %%
batch = next(iter(data.train_dataloader()))

# %%
plot_batch_molecules(batch)

# %% [markdown]
# Sample random prior x_T from N(0,I)

# %%
t = None

# %%
x_T = ddpm_sampler.sample_prior(batch, t=None)

# %%
batch.update(x_T)

# %%
plot_batch_molecules(batch)

# %%
# check if the centre of geometry for the molecules and sampled noise is zero
assert (scatter_mean(batch[properties.R], batch[properties.idx_m], batch[properties.n_atoms]) < 1e-5).all()

# %%
samples_ddpm, num_steps_ddpm, hist_ddpm = ddpm_sampler.denoise(batch, t=t)

samples_jt, num_steps_jt, hist_jt = mrd_jt_sampler.denoise(batch, max_steps=2000)
samples_as, num_steps_as, hist_as = mrd_as_sampler.denoise(batch, max_steps=2000)
samples_itp, num_steps_itp, hist_itp = mrd_itp_sampler.denoise(batch, max_steps=2000)
# Out:
# 100%|██████████| 1000/1000 [01:12<00:00, 13.83it/s]
# 2000it [02:31, 13.23it/s]
# 2000it [04:42,  7.08it/s]
# 903it [00:59, 15.22it/s]

# %%
print("Num steps per example DDPM: ", num_steps_ddpm)
print("Num steps per example MoreRed-JT: ", num_steps_jt)
print("Num steps per example MoreRed-AS: ", num_steps_as)
print("Num steps per example MoreRed-ITP: ", num_steps_itp)
# Out:
# Num steps per example DDPM:  tensor([1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000])
# Num steps per example MoreRed-JT:  tensor([  -1,   -1,   -1,   -1,   -1, 1485,   -1,   -1])
# Num steps per example MoreRed-AS:  tensor([-1, -1, -1, -1, -1, -1, -1, -1])
# Num steps per example MoreRed-ITP:  tensor([859, 839, 878, 858, 640, 903, 849, 811])

# %%
# plot the different examples
tmp_batch = {key: val.clone() for key, val in batch.items()}

print("DDPM:")
tmp_batch.update(samples_ddpm)
plot_batch_molecules(tmp_batch)

print("MoreRed-JT:")
tmp_batch.update(samples_jt)
plot_batch_molecules(tmp_batch)

print("MoreRed-AS:")
tmp_batch.update(samples_as)
plot_batch_molecules(tmp_batch)

print("MoreRed-ITP:")
tmp_batch.update(samples_itp)
plot_batch_molecules(tmp_batch)
# Out:
# DDPM:
# MoreRed-JT:
# MoreRed-AS:
# MoreRed-ITP:

# %%
# check validity of the molecules for each method
# Note this is just a simple check that can't e.g. recognize aromatic rings, check cG-SchNet Gebauer et al. for the analysis scripts

bonds_data = generate_bonds_data().values()

tmp_batch.update(samples_ddpm)
validity_ddpm = check_validity(tmp_batch, *bonds_data)
print("Validity DDPM: ", validity_ddpm['stable_molecules'])

tmp_batch.update(samples_jt)
validity_jt = check_validity(tmp_batch, *bonds_data)
print("Validity MoreRed-JT: ", validity_jt['stable_molecules'])

tmp_batch.update(samples_as)
validity_as = check_validity(tmp_batch, *bonds_data)
print("Validity MoreRed-AS: ", validity_as['stable_molecules'])

tmp_batch.update(samples_itp)
validity_itp = check_validity(tmp_batch, *bonds_data)
print("Validity MoreRed-ITP: ", validity_itp['stable_molecules'])
# Out:
# INFO:root:Bonds data already exists, skipping generation and reloading...
# 100%|██████████| 8/8 [00:00<00:00, 605.75it/s]
# Validity DDPM:  [False, True, True, True, False, True, False, False]
# 100%|██████████| 8/8 [00:00<00:00, 1035.89it/s]
# Validity MoreRed-JT:  [False, True, True, True, False, True, True, True]
# 100%|██████████| 8/8 [00:00<00:00, 1959.27it/s]
# Validity MoreRed-AS:  [True, True, True, True, False, True, False, True]
# 100%|██████████| 8/8 [00:00<00:00, 1506.85it/s]
# Validity MoreRed-ITP:  [False, True, False, True, True, True, False, True]

# %% [markdown]
# # Sample by manually using atomic numbers

# %% [markdown]
# Define the atomic numbers Z for p(X|Z)

# %%
Z = [
    torch.tensor([6, 7, 6, 6, 8, 1, 1, 1, 1, 1, 1, 1]),
    torch.tensor([6, 6, 6, 6, 8, 8, 1, 1, 1, 1, 1, 1]),
    torch.tensor([6, 6, 6, 6, 8, 1, 1, 1, 1, 1, 1, 1, 1]),
]

# %% [markdown]
# Prepare the inputs

# %%
batch = mrd_jt_sampler.prepare_inputs(Z)

# %%
batch.keys()
# Out:
# dict_keys(['_atomic_numbers', '_n_atoms', '_positions', '_cell', '_pbc', '_idx', '_idx_m'])

# %%
# check if the centre of geometry for the molecules and sampled noise is zero
assert (scatter_mean(batch[properties.R], batch[properties.idx_m], batch[properties.n_atoms]) < 1e-5).all()

# %%
x_T = mrd_jt_sampler.sample_prior(batch, t=None)

# %%
batch.update(x_T)

# %%
plot_batch_molecules(batch)

# %%
samples, num_steps, hist = mrd_jt_sampler.denoise(batch, max_steps=2000)
# Out:
# 2000it [02:00, 16.66it/s]

# %%
batch.update(samples)

# %%
plot_batch_molecules(batch)

# %% [markdown]
# # Plot Sampling trajectory

# %%
time_steps = [
    item["t"] for item in hist
]

time_steps = torch.stack(time_steps, dim=0)

time_steps.shape
# Out:
# torch.Size([2000, 3])

# %%
plt.figure(figsize=(10, 5))

for i, traj in enumerate(time_steps.T):
    plt.plot(traj[:num_steps[i]], '-')

plt.show()

# %%
i = 2

mols_traj = [ Atoms(numbers=Z[i], positions=h[properties.R][batch[properties.idx_m] == i]) for h in hist]

mols_traj = mols_traj[:num_steps[i]]

# %%
# plot mols in 4*8 subplots

n_cols = 8
n_rows = 4

fig, axs = plt.subplots(n_rows, n_cols, figsize=(3 * n_cols, 3 * n_rows))
axs = axs.flatten()

# sample equally spaced indices
sub_traj = mols_traj[::len(mols_traj) // (n_cols * n_rows) + 1]

for i, mol in enumerate(sub_traj):
    plot_atoms(mol, axs[i])
    axs[i].axis("off")

plt.tight_layout()
plt.show()
